# %% [markdown]
# <a href="https://colab.research.google.com/github/ZezinhoJoia/curso-de-js-roger-melo/blob/master/CursoBasicoPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Aula01 - Passo a passo de solicitação do desafio**

# %%
import os
#Pd é um apelido para pandas
import pandas as pd
import plotly.express as px



#Lógica da Programação
#Passo 0 - Enteder o desafio que você quer resolver
#Passo 1 - Percorrer todos os arquivos da pasta base de dados
#Passo 2 - Importar as bases de dados de venda

#Passo 3 - Tratar as bases de dados ,Compilar as bases
#Passo 4 - Calcular o produto mais vendido(quantidades)
#Passo 5 - Calcular o produto que mais faturou (em faturamento)
#Passo 6 - Calcular a loja/cidade que mais vendeu em faturamento(criar um grafico)
print("-"*50)
# Out:
# --------------------------------------------------

# %%
#Passo 1 - Percorrer todos os arquivos da pasta base de dados
lista_arquivo = os.listdir("/content/drive/MyDrive/Curso Básico de Python/Vendas")
print(lista_arquivo)
print("-"*50)
# Out:
# ['Devolucoes - São Paulo.csv', 'Vendas - Porto Alegre.csv', 'Devolucoes - Recife.csv', 'Devolucoes - Porto Alegre.csv', 'Vendas - Fortaleza.csv', 'Devolucoes - Goiás.csv', 'Vendas - Salvador.csv', 'Devolucoes - Rio de Janeiro.csv', 'Devolucoes - Salvador.csv', 'Devolucoes - Curitiba.csv', 'Vendas - Rio de Janeiro.csv', 'Devolucoes - Fortaleza.csv', 'Vendas - São Paulo.csv', 'Vendas - Belo Horizonte.csv', 'Devolucoes - Belo Horizonte.csv', 'Vendas - Recife.csv', 'Vendas - Goiás.csv', 'Vendas - Curitiba.csv']
# --------------------------------------------------

# %%
#Passo 1 - Percorrer todos os arquivos da pasta base de dados
lista_arquivo = os.listdir("/content/drive/MyDrive/Curso Básico de Python/Vendas")
print(lista_arquivo)
print("-"*50)
# Out:
# ['Devolucoes - São Paulo.csv', 'Vendas - Porto Alegre.csv', 'Devolucoes - Recife.csv', 'Devolucoes - Porto Alegre.csv', 'Vendas - Fortaleza.csv', 'Devolucoes - Goiás.csv', 'Vendas - Salvador.csv', 'Devolucoes - Rio de Janeiro.csv', 'Devolucoes - Salvador.csv', 'Devolucoes - Curitiba.csv', 'Vendas - Rio de Janeiro.csv', 'Devolucoes - Fortaleza.csv', 'Vendas - São Paulo.csv', 'Vendas - Belo Horizonte.csv', 'Devolucoes - Belo Horizonte.csv', 'Vendas - Recife.csv', 'Vendas - Goiás.csv', 'Vendas - Curitiba.csv']
# --------------------------------------------------

# %% [markdown]
# # **Aula02-Importar Biblioteca e Exibir informações**

# %%
display(lista_arquivo)
print("-"*50)
# Out:
# ['Devolucoes - São Paulo.csv',
#  'Vendas - Porto Alegre.csv',
#  'Devolucoes - Recife.csv',
#  'Devolucoes - Porto Alegre.csv',
#  'Vendas - Fortaleza.csv',
#  'Devolucoes - Goiás.csv',
#  'Vendas - Salvador.csv',
#  'Devolucoes - Rio de Janeiro.csv',
#  'Devolucoes - Salvador.csv',
#  'Devolucoes - Curitiba.csv',
#  'Vendas - Rio de Janeiro.csv',
#  'Devolucoes - Fortaleza.csv',
#  'Vendas - São Paulo.csv',
#  'Vendas - Belo Horizonte.csv',
#  'Devolucoes - Belo Horizonte.csv',
#  'Vendas - Recife.csv',
#  'Vendas - Goiás.csv',
#  'Vendas - Curitiba.csv']
# --------------------------------------------------

# %% [markdown]
# # **Aula03 - Estruturas de Repetição e o Format**

# %%
#Passo 2 - Importar as bases de dados de venda
for arquivo in lista_arquivo:
  #print("\033[2;32;47m")
  #print(arquivo)
  print(f"/content/drive/MyDrive/Curso Básico de Python/Vendas/{arquivo}")
  # print("\033[m")
print("-"*50)
# Out:
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Devolucoes - São Paulo.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Vendas - Porto Alegre.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Devolucoes - Recife.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Devolucoes - Porto Alegre.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Vendas - Fortaleza.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Devolucoes - Goiás.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Vendas - Salvador.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Devolucoes - Rio de Janeiro.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Devolucoes - Salvador.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Devolucoes - Curitiba.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Vendas - Rio de Janeiro.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Devolucoes - Fortaleza.csv
# ...

# %% [markdown]
# **Aula04 - Estruturas de Condições e Texto em Python**

# %%
print("-"*80)
for arquivo in lista_arquivo:
  #print("\033[2;32;47m")
  #print(arquivo)
  if "Vendas" in arquivo:
    print(f"/content/drive/MyDrive/Curso Básico de Python/Vendas/{arquivo}")
  # print("\033[m")

print("-"*80)
# Out:
# --------------------------------------------------------------------------------
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Vendas - Porto Alegre.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Vendas - Fortaleza.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Vendas - Salvador.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Vendas - Rio de Janeiro.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Vendas - São Paulo.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Vendas - Belo Horizonte.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Vendas - Recife.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Vendas - Goiás.csv
# /content/drive/MyDrive/Curso Básico de Python/Vendas/Vendas - Curitiba.csv
# --------------------------------------------------------------------------------

# %% [markdown]
# # **Aula05 -Tabelas e Bases de Dados em Python**

# %%
print("-"*80)
#Criando uma tabela vazia
tabela_total = pd.DataFrame()

for arquivo in lista_arquivo:
  #print("\033[2;32;47m")
  #print(arquivo)
  if "Vendas" in arquivo:
    #print(f"/content/drive/MyDrive/Curso Básico de Python/Vendas/{arquivo}")
    #Importando o Arquivo
    tabela = pd.read_csv(f"/content/drive/MyDrive/Curso Básico de Python/Vendas/{arquivo}")
    #print(arquivo)
    #display(tabela)
    #O novo valor da minha tabela total é o antigo valor  + tabela nova
    tabela_total =tabela_total.append(tabela)

  # print("\033[m")
display(tabela_total)
print("-"*80)
# Out:
# --------------------------------------------------------------------------------
# <ipython-input-8-f45f87ebd740>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total =tabela_total.append(tabela)
# <ipython-input-8-f45f87ebd740>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total =tabela_total.append(tabela)
# <ipython-input-8-f45f87ebd740>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total =tabela_total.append(tabela)
# <ipython-input-8-f45f87ebd740>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total =tabela_total.append(tabela)
# ...

# %% [markdown]
# Aula06 - Indicadores e Graficos em Python
# #Passo 4 - Calcular o produto mais vendido(quantidades)

# %%
tabela_produtos = tabela_total.groupby("Produto").sum()
tabela_produtos = tabela_produtos[["Quantidade Vendida","Preco Unitario"]].sort_values(by="Quantidade Vendida",ascending=False)
display(tabela_produtos)
# Out:
# <ipython-input-9-474b0c8c68fc>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tabela_produtos = tabela_total.groupby("Produto").sum()
#             Quantidade Vendida  Preco Unitario
# Produto
# iPhone                    8974        15778100
# Televisão                 5931         4905000
# Notebook                  3249         3717000
# Android                   3183         3631200
# SmartWatch                2980         1393000
# Tablet                    2921         1556800
# Câmera                    2805         2020200

# %% [markdown]
# # **#Passo 5 - Calcular o produto que mais faturou (em faturamento)**

# %%
tabela_total["Faturamento"]=tabela_total["Quantidade Vendida"] * tabela_total["Preco Unitario"]
#display(tabela_total)
tabela_faturamento = tabela_total.groupby("Produto").sum()
tabela_faturamento =tabela_faturamento[["Faturamento"]].sort_values(by ="Faturamento",ascending = False)
display(tabela_faturamento)
# Out:
# <ipython-input-10-97f2d7dbb544>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tabela_faturamento = tabela_total.groupby("Produto").sum()
#             Faturamento
# Produto
# iPhone         47562200
# Televisão      14827500
# Notebook       11371500
# Android        10822200
# Câmera          5890500
# Tablet          4673600
# SmartWatch      4172000

# %% [markdown]
# #Passo 6 - Calcular a loja/cidade que mais vendeu em faturamento(criar um grafico)

# %%
tabela_lojas = tabela_total.groupby("Loja").sum()
tabela_lojas =tabela_lojas[["Faturamento"]]
display(tabela_lojas)
# Out:
# <ipython-input-11-7e2300e27f90>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tabela_lojas = tabela_total.groupby("Loja").sum()
#                 Faturamento
# Loja
# Belo Horizonte      6480300
# Curitiba            7060500
# Fortaleza          14087900
# Goiás               7441800
# Porto Alegre        6868600
# Recife              7303000
# Rio de Janeiro     14867800
# Salvador           13111300
# São Paulo          22098300

# %% [markdown]
# # **#Passo 6 - Calcular a loja/cidade que mais vendeu em faturamento(criar um grafico)**

# %%
#Importar o plotly.express (biblioteca para construir graficos)
grafico = px.bar(tabela_lojas, x=tabela_lojas.index,y="Faturamento")#(Linha p/ Construir o grafico))
grafico.show()#Linha p/ Exibir o grafico
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
